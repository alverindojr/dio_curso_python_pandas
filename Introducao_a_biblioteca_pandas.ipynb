# %% [markdown]
# **Python para análise de Dados (Pandas)**

# %%
#importando a biblioteca pandas
import pandas as pd

# %%
#importando a planilha no dataframe
df = pd.read_csv("/content/drive/MyDrive/Datasets/Gapminder.csv",error_bad_lines=False,sep=";")

# %%
#imprimindo as 5 primeiras linhas
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#renomeando os títulos das colunas
df = df.rename(columns={"country":"pais","continent":"continente","year":"ano","lifeExp":"expectativa_de_vida","pop":"populacao","gdpPercap":"renda_per_capita"})
df.head()
# Out:
#           pais continente  ...  populacao  renda_per_capita
# 0  Afghanistan       Asia  ...    8425333        779.445314
# 1  Afghanistan       Asia  ...    9240934        820.853030
# 2  Afghanistan       Asia  ...   10267083        853.100710
# 3  Afghanistan       Asia  ...   11537966        836.197138
# 4  Afghanistan       Asia  ...   13079460        739.981106
#
# [5 rows x 6 columns]

# %%
#retornar o total de linhas e colunas do dataframe
df.shape
# Out:
# (3312, 6)

# %%
#retornar o nome das colunas 
df.columns
# Out:
# Index(['pais', 'continente', 'ano', 'expectativa_de_vida', 'populacao',
#        'renda_per_capita'],
#       dtype='object')

# %%
#retornar o tipo de cada coluna
df.dtypes
# Out:
# pais                    object
# continente              object
# ano                      int64
# expectativa_de_vida    float64
# populacao                int64
# renda_per_capita       float64
# dtype: object

# %%
#retornar as ultimas linhas 
df.tail()
# Out:
#           pais continente  ...  populacao  renda_per_capita
# 3307  Zimbabwe     Africa  ...    9216418        706.157306
# 3308  Zimbabwe     Africa  ...   10704340        693.420786
# 3309  Zimbabwe     Africa  ...   11404948        792.449960
# 3310  Zimbabwe     Africa  ...   11926563        672.038623
# 3311  Zimbabwe     Africa  ...   12311143        469.709298
#
# [5 rows x 6 columns]

# %%
#retornar informacoes estatisticas do dataframe
df.describe()
# Out:
#                ano  expectativa_de_vida     populacao  renda_per_capita
# count  3312.000000          3312.000000  3.312000e+03       3312.000000
# mean   1980.301630            65.246871  3.161489e+07      11317.115805
# std      16.927294            11.768412  1.041193e+08      11369.142739
# min    1950.000000            23.599000  5.941200e+04        241.165877
# 25%    1967.000000            58.337500  2.678572e+06       2514.625266
# 50%    1982.000000            69.610000  7.557218e+06       7838.505123
# 75%    1996.000000            73.657750  1.958522e+07      17357.879170
# max    2007.000000            82.670000  1.318683e+09     113523.132900

# %%
#retornar os continentes sem repetições
df['continente'].unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'Americas', nan, 'FSU', 'Oceania'],
#       dtype=object)

# %%
#retornar os dados do continente Oceania
filtro = df['continente'] == 'Oceania'
df.loc[filtro]
# Out:
#                  pais continente  ...  populacao  renda_per_capita
# 975              Fiji    Oceania  ...     421869       2039.393277
# 976              Fiji    Oceania  ...     485000       2170.073285
# 977              Fiji    Oceania  ...     544000       2797.759484
# 978              Fiji    Oceania  ...     599339       3182.569600
# 979              Fiji    Oceania  ...     658906       3209.257468
# ...               ...        ...  ...        ...               ...
# 2696  Solomon Islands    Oceania  ...     300694       1783.648762
# 2697  Solomon Islands    Oceania  ...     358713       2109.894257
# 2698  Solomon Islands    Oceania  ...     424265       2252.491044
# 2699  Solomon Islands    Oceania  ...     494786       1530.496068
# 2700  Solomon Islands    Oceania  ...     566842       1829.317402
#
# [74 rows x 6 columns]

# %%
#retornar quantos paises tem por continente sem repetir (as informacoes estao vindo todos os anos)
df.groupby('continente')['pais'].nunique()
# Out:
# continente
# Africa      51
# Americas    25
# Asia        41
# Europe      35
# FSU          6
# Oceania      3
# Name: pais, dtype: int64

# %%
#retornar a media da expectativa de vida por ano
df.groupby('ano')['expectativa_de_vida'].mean()
# Out:
# ano
# 1950    62.002568
# 1951    65.904167
# 1952    49.206867
# 1953    66.674563
# 1954    67.459817
# 1955    67.806757
# 1956    67.950637
# 1957    51.614590
# 1958    68.815936
# 1959    68.226579
# 1960    68.470837
# 1961    68.862480
# 1962    54.035234
# 1963    69.595735
# 1964    70.063105
# 1965    70.259881
# 1966    70.447526
# 1967    56.263629
# 1968    70.689081
# 1969    70.653896
# 1970    70.961141
# 1971    71.103976
# 1972    58.474481
# 1973    71.500338
# 1974    71.778504
# 1975    71.939218
# 1976    72.158050
# 1977    60.429090
# 1978    72.717567
# 1979    73.018717
# 1980    73.064524
# 1981    73.337399
# 1982    62.365871
# 1983    73.787778
# 1984    74.100741
# 1985    74.112222
# 1986    74.452222
# 1987    63.984860
# 1988    74.760000
# 1989    74.924444
# 1990    74.283437
# 1991    74.374848
# 1992    65.008443
# 1993    74.324545
# 1994    74.456667
# 1995    74.552727
# 1996    75.029394
# 1997    65.873799
# 1998    75.569697
# ...
